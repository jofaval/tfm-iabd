# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
class BoxOfficeMojo():
  url_base ="https://www.boxofficemojo.com"
  url = ""
  frequency = "weekly" # frequency of time [daily, weekend, weekly, monthly, quarterly, yearly]
  since_year = 0
  to_year = 0
  actual_year = 0
  actual_week = 1 # number of weeks from 01 to 52
  weeks_per_year = 52
  query_order = "?sort=numWeeksInRelease&sortDir=asc&ref_=bo_wl__resort#table"
  labels = ['rank', 'rank last week', 'release', 'gross per week', 'gross change/week', 'theaters', 'number of theaters change', 'per theater average gross', 'total gross', 'number ow weeks in release', 'distributor', 'actual year', 'actual week', 'origin']
  json_schema = {
      'rank': '',
      'rank last week': '',
      'release': '',
      'gross per week': '',
      'gross change/week': '',
      'theaters': '',
      'number of theaters change': '',
      'per theater average gross': '',
      'total gross': '',
      'number ow weeks in release': '',
      'distributor': '',
      'actual year': '',
      'actual week': '',
      'origin': 'box-office-mojo'
  }

  def __init__(self, since_year, to_year):
    self.since_year = since_year
    self.to_year = to_year
    self.actual_year = since_year

  def built_url(self):
    if self.actual_week < 10:
      actual_week = "0" + str(self.actual_week)
    else:
      actual_week = str(self.actual_week)

    self.url = self.url_base + "/" + self.frequency + "/" + str(self.actual_year) + "W" + actual_week + "/" + self.query_order

  def get_next_url(self):
    if self.actual_week < 52:
      self.built_url()
      self.actual_week = self.actual_week + 1
    else:
      if self.actual_year < self.to_year:
        self.built_url()
        self.actual_year = self.actual_year + 1
        self.actual_week = 1
      else:
        self.url = ""

    return self.url

  def get_page_content(self):
    url = self.get_next_url()
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    content = BeautifulSoup(page.content)
    tr_list = content.find_all("tr", {'class': 'mojo-annotation-isNewThisWeek'})
    #remove label cols
    tr_list.pop(0)

    movies_list = []
    for tr in tr_list:
      movie = []
      for td in tr:
        text = td.get_text().strip()
        if text != "" and text != "true" and text != "false":
          if text == "-":
            text = "0"
          movie.append(text)
      
      movie.append(self.actual_year)
      movie.append(self.actual_week)
      movie.append('box-office-mojo')

      movies_list.append(movie)
    
    return movies_list

  def extract_and_export_data(self):
    print(f'Initializing process')
    total_weeks = (self.to_year - self.since_year) * self.weeks_per_year
    advice_counter1 = int(total_weeks / 4 ) * 3 # 75% progress
    advice_counter2 = int(total_weeks / 4 ) * 2 # 50% progress
    advice_counter3 = int(total_weeks / 4 ) # 25% progress

    movies_list = []
    while total_weeks > 0:
      print(f'Extracting data... Year:{self.actual_year} Week:{self.actual_week}')      
      movies = self.get_page_content()
      movies_list.extend(movies)
      total_weeks = total_weeks - 1

    print(f'Data extracted!') 
    self.export_to_csv_file(movies_list)

  def export_to_csv_file(self, movies_list):
    print(f'Exporting data... ') 
    movies_list_df = pd.DataFrame(movies_list, columns = self.labels)
    file_name =  'movies_' + str(self.since_year) + '-' + str(self.to_year) + '.csv'
    movies_list_df.to_csv(file_name, index = 0, columns = self.labels)
    print(f'Data exported! \nProcess finalized!')

# %%
mojo = BoxOfficeMojo(since_year = 2012, to_year = 2020)

# %%
mojo.extract_and_export_data()
# Out:
# Initializing process
# Extracting data... Year:2012 Week:1
# Extracting data... Year:2012 Week:2
# Extracting data... Year:2012 Week:3
# Extracting data... Year:2012 Week:4
# Extracting data... Year:2012 Week:5
# Extracting data... Year:2012 Week:6
# Extracting data... Year:2012 Week:7
# Extracting data... Year:2012 Week:8
# Extracting data... Year:2012 Week:9
# Extracting data... Year:2012 Week:10
# Extracting data... Year:2012 Week:11
# Extracting data... Year:2012 Week:12
# Extracting data... Year:2012 Week:13
# Extracting data... Year:2012 Week:14
# Extracting data... Year:2012 Week:15
# Extracting data... Year:2012 Week:16
# Extracting data... Year:2012 Week:17
# Extracting data... Year:2012 Week:18
# Extracting data... Year:2012 Week:19
# Extracting data... Year:2012 Week:20
# Extracting data... Year:2012 Week:21
# Extracting data... Year:2012 Week:22
# Extracting data... Year:2012 Week:23
# Extracting data... Year:2012 Week:24
# Extracting data... Year:2012 Week:25
# Extracting data... Year:2012 Week:26
# Extracting data... Year:2012 Week:27
# Extracting data... Year:2012 Week:28
# Extracting data... Year:2012 Week:29
# Extracting data... Year:2012 Week:30
# Extracting data... Year:2012 Week:31
# Extracting data... Year:2012 Week:32
# Extracting data... Year:2012 Week:33
# Extracting data... Year:2012 Week:34
# Extracting data... Year:2012 Week:35
# Extracting data... Year:2012 Week:36
# Extracting data... Year:2012 Week:37
# Extracting data... Year:2012 Week:38
# Extracting data... Year:2012 Week:39
# Extracting data... Year:2012 Week:40
# Extracting data... Year:2012 Week:41
# Extracting data... Year:2012 Week:42
# Extracting data... Year:2012 Week:43
# Extracting data... Year:2012 Week:44
# Extracting data... Year:2012 Week:45
# Extracting data... Year:2012 Week:46
# Extracting data... Year:2012 Week:47
# Extracting data... Year:2012 Week:48
# Extracting data... Year:2012 Week:49
# Extracting data... Year:2012 Week:50
# Extracting data... Year:2012 Week:51
# Extracting data... Year:2012 Week:52
# Extracting data... Year:2013 Week:1
# Extracting data... Year:2013 Week:2
# Extracting data... Year:2013 Week:3
# Extracting data... Year:2013 Week:4
# Extracting data... Year:2013 Week:5
# Extracting data... Year:2013 Week:6
# Extracting data... Year:2013 Week:7
# Extracting data... Year:2013 Week:8
# Extracting data... Year:2013 Week:9
# Extracting data... Year:2013 Week:10
# Extracting data... Year:2013 Week:11
# Extracting data... Year:2013 Week:12
# Extracting data... Year:2013 Week:13
# Extracting data... Year:2013 Week:14
# Extracting data... Year:2013 Week:15
# Extracting data... Year:2013 Week:16
# Extracting data... Year:2013 Week:17
# Extracting data... Year:2013 Week:18
# Extracting data... Year:2013 Week:19
# Extracting data... Year:2013 Week:20
# Extracting data... Year:2013 Week:21
# Extracting data... Year:2013 Week:22
# Extracting data... Year:2013 Week:23
# Extracting data... Year:2013 Week:24
# Extracting data... Year:2013 Week:25
# Extracting data... Year:2013 Week:26
# Extracting data... Year:2013 Week:27
# Extracting data... Year:2013 Week:28
# Extracting data... Year:2013 Week:29
# Extracting data... Year:2013 Week:30
# Extracting data... Year:2013 Week:31
# Extracting data... Year:2013 Week:32
# Extracting data... Year:2013 Week:33
# Extracting data... Year:2013 Week:34
# Extracting data... Year:2013 Week:35
# Extracting data... Year:2013 Week:36
# Extracting data... Year:2013 Week:37
# Extracting data... Year:2013 Week:38
# Extracting data... Year:2013 Week:39
# Extracting data... Year:2013 Week:40
# Extracting data... Year:2013 Week:41
# Extracting data... Year:2013 Week:42
# Extracting data... Year:2013 Week:43
# Extracting data... Year:2013 Week:44
# Extracting data... Year:2013 Week:45
# Extracting data... Year:2013 Week:46
# Extracting data... Year:2013 Week:47
# Extracting data... Year:2013 Week:48
# Extracting data... Year:2013 Week:49
# Extracting data... Year:2013 Week:50
# Extracting data... Year:2013 Week:51
# Extracting data... Year:2013 Week:52
# Extracting data... Year:2014 Week:1
# Extracting data... Year:2014 Week:2
# Extracting data... Year:2014 Week:3
# Extracting data... Year:2014 Week:4
# Extracting data... Year:2014 Week:5
# Extracting data... Year:2014 Week:6
# Extracting data... Year:2014 Week:7
# Extracting data... Year:2014 Week:8
# Extracting data... Year:2014 Week:9
# Extracting data... Year:2014 Week:10
# Extracting data... Year:2014 Week:11
# Extracting data... Year:2014 Week:12
# Extracting data... Year:2014 Week:13
# Extracting data... Year:2014 Week:14
# Extracting data... Year:2014 Week:15
# Extracting data... Year:2014 Week:16
# Extracting data... Year:2014 Week:17
# Extracting data... Year:2014 Week:18
# Extracting data... Year:2014 Week:19
# Extracting data... Year:2014 Week:20
# Extracting data... Year:2014 Week:21
# Extracting data... Year:2014 Week:22
# Extracting data... Year:2014 Week:23
# Extracting data... Year:2014 Week:24
# Extracting data... Year:2014 Week:25
# Extracting data... Year:2014 Week:26
# Extracting data... Year:2014 Week:27
# Extracting data... Year:2014 Week:28
# Extracting data... Year:2014 Week:29
# Extracting data... Year:2014 Week:30
# Extracting data... Year:2014 Week:31
# Extracting data... Year:2014 Week:32
# Extracting data... Year:2014 Week:33
# Extracting data... Year:2014 Week:34
# Extracting data... Year:2014 Week:35
# Extracting data... Year:2014 Week:36
# Extracting data... Year:2014 Week:37
# Extracting data... Year:2014 Week:38
# Extracting data... Year:2014 Week:39
# Extracting data... Year:2014 Week:40
# Extracting data... Year:2014 Week:41
# Extracting data... Year:2014 Week:42
# Extracting data... Year:2014 Week:43
# Extracting data... Year:2014 Week:44
# Extracting data... Year:2014 Week:45
# Extracting data... Year:2014 Week:46
# Extracting data... Year:2014 Week:47
# Extracting data... Year:2014 Week:48
# Extracting data... Year:2014 Week:49
# Extracting data... Year:2014 Week:50
# Extracting data... Year:2014 Week:51
# Extracting data... Year:2014 Week:52
# Extracting data... Year:2015 Week:1
# Extracting data... Year:2015 Week:2
# Extracting data... Year:2015 Week:3
# Extracting data... Year:2015 Week:4
# Extracting data... Year:2015 Week:5
# Extracting data... Year:2015 Week:6
# Extracting data... Year:2015 Week:7
# Extracting data... Year:2015 Week:8
# Extracting data... Year:2015 Week:9
# Extracting data... Year:2015 Week:10
# Extracting data... Year:2015 Week:11
# Extracting data... Year:2015 Week:12
# Extracting data... Year:2015 Week:13
# Extracting data... Year:2015 Week:14
# Extracting data... Year:2015 Week:15
# Extracting data... Year:2015 Week:16
# Extracting data... Year:2015 Week:17
# Extracting data... Year:2015 Week:18
# Extracting data... Year:2015 Week:19
# Extracting data... Year:2015 Week:20
# Extracting data... Year:2015 Week:21
# Extracting data... Year:2015 Week:22
# Extracting data... Year:2015 Week:23
# Extracting data... Year:2015 Week:24
# Extracting data... Year:2015 Week:25
# Extracting data... Year:2015 Week:26
# Extracting data... Year:2015 Week:27
# Extracting data... Year:2015 Week:28
# Extracting data... Year:2015 Week:29
# Extracting data... Year:2015 Week:30
# Extracting data... Year:2015 Week:31
# Extracting data... Year:2015 Week:32
# Extracting data... Year:2015 Week:33
# Extracting data... Year:2015 Week:34
# Extracting data... Year:2015 Week:35
# Extracting data... Year:2015 Week:36
# Extracting data... Year:2015 Week:37
# Extracting data... Year:2015 Week:38
# Extracting data... Year:2015 Week:39
# Extracting data... Year:2015 Week:40
# Extracting data... Year:2015 Week:41
# Extracting data... Year:2015 Week:42
# Extracting data... Year:2015 Week:43
# Extracting data... Year:2015 Week:44
# Extracting data... Year:2015 Week:45
# Extracting data... Year:2015 Week:46
# Extracting data... Year:2015 Week:47
# Extracting data... Year:2015 Week:48
# Extracting data... Year:2015 Week:49
# Extracting data... Year:2015 Week:50
# Extracting data... Year:2015 Week:51
# Extracting data... Year:2015 Week:52
# Extracting data... Year:2016 Week:1
# Extracting data... Year:2016 Week:2
# Extracting data... Year:2016 Week:3
# Extracting data... Year:2016 Week:4
# Extracting data... Year:2016 Week:5
# Extracting data... Year:2016 Week:6
# Extracting data... Year:2016 Week:7
# Extracting data... Year:2016 Week:8
# Extracting data... Year:2016 Week:9
# Extracting data... Year:2016 Week:10
# Extracting data... Year:2016 Week:11
# Extracting data... Year:2016 Week:12
# Extracting data... Year:2016 Week:13
# Extracting data... Year:2016 Week:14
# Extracting data... Year:2016 Week:15
# Extracting data... Year:2016 Week:16
# Extracting data... Year:2016 Week:17
# Extracting data... Year:2016 Week:18
# Extracting data... Year:2016 Week:19
# Extracting data... Year:2016 Week:20
# Extracting data... Year:2016 Week:21
# Extracting data... Year:2016 Week:22
# Extracting data... Year:2016 Week:23
# Extracting data... Year:2016 Week:24
# Extracting data... Year:2016 Week:25
# Extracting data... Year:2016 Week:26
# Extracting data... Year:2016 Week:27
# Extracting data... Year:2016 Week:28
# Extracting data... Year:2016 Week:29
# Extracting data... Year:2016 Week:30
# Extracting data... Year:2016 Week:31
# Extracting data... Year:2016 Week:32
# Extracting data... Year:2016 Week:33
# Extracting data... Year:2016 Week:34
# Extracting data... Year:2016 Week:35
# Extracting data... Year:2016 Week:36
# Extracting data... Year:2016 Week:37
# Extracting data... Year:2016 Week:38
# Extracting data... Year:2016 Week:39
# Extracting data... Year:2016 Week:40
# Extracting data... Year:2016 Week:41
# Extracting data... Year:2016 Week:42
# Extracting data... Year:2016 Week:43
# Extracting data... Year:2016 Week:44
# Extracting data... Year:2016 Week:45
# Extracting data... Year:2016 Week:46
# Extracting data... Year:2016 Week:47
# Extracting data... Year:2016 Week:48
# Extracting data... Year:2016 Week:49
# Extracting data... Year:2016 Week:50
# Extracting data... Year:2016 Week:51
# Extracting data... Year:2016 Week:52
# Extracting data... Year:2017 Week:1
# Extracting data... Year:2017 Week:2
# Extracting data... Year:2017 Week:3
# Extracting data... Year:2017 Week:4
# Extracting data... Year:2017 Week:5
# Extracting data... Year:2017 Week:6
# Extracting data... Year:2017 Week:7
# Extracting data... Year:2017 Week:8
# Extracting data... Year:2017 Week:9
# Extracting data... Year:2017 Week:10
# Extracting data... Year:2017 Week:11
# Extracting data... Year:2017 Week:12
# Extracting data... Year:2017 Week:13
# Extracting data... Year:2017 Week:14
# Extracting data... Year:2017 Week:15
# Extracting data... Year:2017 Week:16
# Extracting data... Year:2017 Week:17
# Extracting data... Year:2017 Week:18
# Extracting data... Year:2017 Week:19
# Extracting data... Year:2017 Week:20
# Extracting data... Year:2017 Week:21
# Extracting data... Year:2017 Week:22
# Extracting data... Year:2017 Week:23
# Extracting data... Year:2017 Week:24
# Extracting data... Year:2017 Week:25
# Extracting data... Year:2017 Week:26
# Extracting data... Year:2017 Week:27
# Extracting data... Year:2017 Week:28
# Extracting data... Year:2017 Week:29
# Extracting data... Year:2017 Week:30
# Extracting data... Year:2017 Week:31
# Extracting data... Year:2017 Week:32
# Extracting data... Year:2017 Week:33
# Extracting data... Year:2017 Week:34
# Extracting data... Year:2017 Week:35
# Extracting data... Year:2017 Week:36
# Extracting data... Year:2017 Week:37
# Extracting data... Year:2017 Week:38
# Extracting data... Year:2017 Week:39
# Extracting data... Year:2017 Week:40
# Extracting data... Year:2017 Week:41
# Extracting data... Year:2017 Week:42
# Extracting data... Year:2017 Week:43
# Extracting data... Year:2017 Week:44
# Extracting data... Year:2017 Week:45
# Extracting data... Year:2017 Week:46
# Extracting data... Year:2017 Week:47
# Extracting data... Year:2017 Week:48
# Extracting data... Year:2017 Week:49
# Extracting data... Year:2017 Week:50
# Extracting data... Year:2017 Week:51
# Extracting data... Year:2017 Week:52
# Extracting data... Year:2018 Week:1
# Extracting data... Year:2018 Week:2
# Extracting data... Year:2018 Week:3
# Extracting data... Year:2018 Week:4
# Extracting data... Year:2018 Week:5
# Extracting data... Year:2018 Week:6
# Extracting data... Year:2018 Week:7
# Extracting data... Year:2018 Week:8
# Extracting data... Year:2018 Week:9
# Extracting data... Year:2018 Week:10
# Extracting data... Year:2018 Week:11
# Extracting data... Year:2018 Week:12
# Extracting data... Year:2018 Week:13
# Extracting data... Year:2018 Week:14
# Extracting data... Year:2018 Week:15
# Extracting data... Year:2018 Week:16
# Extracting data... Year:2018 Week:17
# Extracting data... Year:2018 Week:18
# Extracting data... Year:2018 Week:19
# Extracting data... Year:2018 Week:20
# Extracting data... Year:2018 Week:21
# Extracting data... Year:2018 Week:22
# Extracting data... Year:2018 Week:23
# Extracting data... Year:2018 Week:24
# Extracting data... Year:2018 Week:25
# Extracting data... Year:2018 Week:26
# Extracting data... Year:2018 Week:27
# Extracting data... Year:2018 Week:28
# Extracting data... Year:2018 Week:29
# Extracting data... Year:2018 Week:30
# Extracting data... Year:2018 Week:31
# Extracting data... Year:2018 Week:32
# Extracting data... Year:2018 Week:33
# Extracting data... Year:2018 Week:34
# Extracting data... Year:2018 Week:35
# Extracting data... Year:2018 Week:36
# Extracting data... Year:2018 Week:37
# Extracting data... Year:2018 Week:38
# Extracting data... Year:2018 Week:39
# Extracting data... Year:2018 Week:40
# Extracting data... Year:2018 Week:41
# Extracting data... Year:2018 Week:42
# Extracting data... Year:2018 Week:43
# Extracting data... Year:2018 Week:44
# Extracting data... Year:2018 Week:45
# Extracting data... Year:2018 Week:46
# Extracting data... Year:2018 Week:47
# Extracting data... Year:2018 Week:48
# Extracting data... Year:2018 Week:49
# Extracting data... Year:2018 Week:50
# Extracting data... Year:2018 Week:51
# Extracting data... Year:2018 Week:52
# Extracting data... Year:2019 Week:1
# Extracting data... Year:2019 Week:2
# Extracting data... Year:2019 Week:3
# Extracting data... Year:2019 Week:4
# Extracting data... Year:2019 Week:5
# Extracting data... Year:2019 Week:6
# Extracting data... Year:2019 Week:7
# Extracting data... Year:2019 Week:8
# Extracting data... Year:2019 Week:9
# Extracting data... Year:2019 Week:10
# Extracting data... Year:2019 Week:11
# Extracting data... Year:2019 Week:12
# Extracting data... Year:2019 Week:13
# Extracting data... Year:2019 Week:14
# Extracting data... Year:2019 Week:15
# Extracting data... Year:2019 Week:16
# Extracting data... Year:2019 Week:17
# Extracting data... Year:2019 Week:18
# Extracting data... Year:2019 Week:19
# Extracting data... Year:2019 Week:20
# Extracting data... Year:2019 Week:21
# Extracting data... Year:2019 Week:22
# Extracting data... Year:2019 Week:23
# Extracting data... Year:2019 Week:24
# Extracting data... Year:2019 Week:25
# Extracting data... Year:2019 Week:26
# Extracting data... Year:2019 Week:27
# Extracting data... Year:2019 Week:28
# Extracting data... Year:2019 Week:29
# Extracting data... Year:2019 Week:30
# Extracting data... Year:2019 Week:31
# Extracting data... Year:2019 Week:32
# Extracting data... Year:2019 Week:33
# Extracting data... Year:2019 Week:34
# Extracting data... Year:2019 Week:35
# Extracting data... Year:2019 Week:36
# Extracting data... Year:2019 Week:37
# Extracting data... Year:2019 Week:38
# Extracting data... Year:2019 Week:39
# Extracting data... Year:2019 Week:40
# Extracting data... Year:2019 Week:41
# Extracting data... Year:2019 Week:42
# Extracting data... Year:2019 Week:43
# Extracting data... Year:2019 Week:44
# Extracting data... Year:2019 Week:45
# Extracting data... Year:2019 Week:46
# Extracting data... Year:2019 Week:47
# Extracting data... Year:2019 Week:48
# Extracting data... Year:2019 Week:49
# Extracting data... Year:2019 Week:50
# Extracting data... Year:2019 Week:51
# Extracting data... Year:2019 Week:52
# Data extracted!
# Exporting data...
# Data exported!
# Process finalized!
